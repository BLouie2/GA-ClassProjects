# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
boxing = pd.read_csv("bouts_out_new.csv")

# %%
boxing.describe()
# Out:
#                age_A          age_B       height_A       height_B  \
# count  352888.000000  257935.000000  249246.000000  134640.000000
# mean       24.416041      26.583345     172.786657     172.882657
# std         6.523590      11.823224       9.130127       9.430631
# min       -74.000000     -74.000000       2.000000      15.000000
# 25%        21.000000      23.000000     166.000000     167.000000
# 50%        24.000000      26.000000     173.000000     173.000000
# 75%        27.000000      30.000000     178.000000     179.000000
# max      1818.000000    2016.000000     255.000000     255.000000
#
#              reach_A       reach_B       weight_A       weight_B  \
# count  112342.000000  37873.000000  135573.000000  130358.000000
# mean      178.848605    179.001030     146.340636     147.089484
# std        12.002404     14.867537      30.240142      30.624890
# min         5.000000      1.000000      10.000000       2.000000
# ...

# %%
boxing.head(20)
# Out:
#     age_A  age_B  height_A  height_B  reach_A  reach_B  stance_A  stance_B  \
# 0    35.0   27.0     179.0     175.0    178.0    179.0  orthodox  orthodox
# 1    26.0   31.0     175.0     185.0    179.0    185.0  orthodox  orthodox
# 2    28.0   26.0     176.0     175.0      NaN    179.0  orthodox  orthodox
# 3    25.0   29.0     175.0     174.0    179.0    180.0  orthodox  orthodox
# 4    25.0   35.0     175.0     170.0    179.0    170.0  orthodox  orthodox
# 5    24.0   31.0     175.0     175.0    179.0    178.0  orthodox  orthodox
# 6    23.0   31.0     175.0     175.0    179.0    188.0  orthodox  orthodox
# 7    23.0   31.0     175.0     177.0    179.0    175.0  orthodox  orthodox
# 8    36.0   23.0     173.0     175.0    183.0    179.0  orthodox  orthodox
# 9    27.0   22.0     177.0     175.0    183.0    179.0  southpaw  southpaw
# 10   22.0   28.0     175.0     177.0    179.0    175.0  orthodox  orthodox
# ...

# %%
boxing.tail(20)
# Out:
#         age_A  age_B  height_A  height_B  reach_A  reach_B  stance_A  \
# 387407   21.0   19.0       NaN       NaN      NaN      NaN  orthodox
# 387408   21.0    NaN       NaN       NaN      NaN      NaN  orthodox
# 387409   21.0    NaN       NaN       NaN      NaN      NaN  orthodox
# 387410   21.0    NaN       NaN       NaN      NaN      NaN  orthodox
# 387411   21.0   19.0       NaN       NaN      NaN      NaN  orthodox
# 387412   21.0   27.0       NaN       NaN      NaN      NaN  orthodox
# 387413   21.0   20.0       NaN       NaN      NaN      NaN  orthodox
# 387414   21.0   27.0       NaN       NaN      NaN      NaN  orthodox
# 387415   21.0   27.0       NaN       NaN      NaN      NaN  orthodox
# 387416   21.0    NaN       NaN       NaN      NaN      NaN  orthodox
# 387417   21.0   27.0       NaN       NaN      NaN      NaN  orthodox
# 387418   21.0    NaN       NaN       NaN      NaN      NaN  orthodox
# 387419   21.0    NaN       NaN       NaN      NaN      NaN  orthodox
# ...

# %%
boxing.shape
# Out:
# (387427, 26)

# %%
boxing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 387427 entries, 0 to 387426
# Data columns (total 26 columns):
# age_A       352888 non-null float64
# age_B       257935 non-null float64
# height_A    249246 non-null float64
# height_B    134640 non-null float64
# reach_A     112342 non-null float64
# reach_B     37873 non-null float64
# stance_A    231009 non-null object
# stance_B    231009 non-null object
# weight_A    135573 non-null float64
# weight_B    130358 non-null float64
# won_A       387427 non-null int64
# won_B       387427 non-null int64
# lost_A      387427 non-null int64
# lost_B      387427 non-null int64
# drawn_A     387427 non-null int64
# drawn_B     387427 non-null int64
# kos_A       387427 non-null int64
# kos_B       387348 non-null float64
# result      387427 non-null object
# decision    387427 non-null object
# judge1_A    52248 non-null float64
# judge1_B    52060 non-null float64
# judge2_A    70371 non-null float64
# ...

# %%
boxing.columns
# Out:
# Index(['age_A', 'age_B', 'height_A', 'height_B', 'reach_A', 'reach_B',
#        'stance_A', 'stance_B', 'weight_A', 'weight_B', 'won_A', 'won_B',
#        'lost_A', 'lost_B', 'drawn_A', 'drawn_B', 'kos_A', 'kos_B', 'result',
#        'decision', 'judge1_A', 'judge1_B', 'judge2_A', 'judge2_B', 'judge3_A',
#        'judge3_B'],
#       dtype='object')

# %%
boxing[['weight_A', 'weight_B']].head()
# Out:
#    weight_A  weight_B
# 0     160.0     160.0
# 1     164.0     164.0
# 2     154.0     154.0
# 3     155.0     155.0
# 4     155.0       NaN

# %%
boxing[['weight_A', 'weight_B']].mean()
# Out:
# weight_A    146.340636
# weight_B    147.089484
# dtype: float64

# %%
boxing.groupby('stance_A').mean()
# Out:
#               age_A      age_B    height_A    height_B     reach_A  \
# stance_A
# orthodox  24.849156  27.172994  173.909424  173.927637  179.577193
# southpaw  24.446050  27.018679  172.084873  171.858057  178.171716
#
#              reach_B    weight_A    weight_B     won_A      won_B    ...      \
# stance_A                                                             ...
# orthodox  179.863829  148.704362  149.557706  23.28645  14.289094    ...
# southpaw  177.604984  139.571069  140.424654  19.98428  13.311377    ...
#
#            drawn_A   drawn_B      kos_A     kos_B   judge1_A   judge1_B  \
# stance_A
# orthodox  2.107600  2.045602  11.674497  6.449585  67.775907  64.409719
# southpaw  1.469799  1.851706   9.713368  5.960042  69.393515  65.584177
#
#            judge2_A   judge2_B   judge3_A   judge3_B
# stance_A
# orthodox  62.728732  59.608414  64.604361  61.727553
# southpaw  67.223460  63.557711  68.595979  65.156395
#
# [2 rows x 22 columns]

# %%
boxing.groupby(['stance_A', 'result']).mean()
# Out:
#                      age_A      age_B    height_A    height_B     reach_A  \
# stance_A result
# orthodox draw    24.610482  25.414263  171.997518  172.395198  177.887915
#          win_A   24.710483  27.469900  174.049135  173.908766  179.740118
#          win_B   26.417505  25.547055  173.481216  174.690243  178.625039
# southpaw draw    23.682942  25.089724  170.465870  170.303356  177.525886
#          win_A   24.400597  27.231199  172.165085  171.784058  178.160571
#          win_B   25.494453  25.725064  171.914969  173.319574  178.649318
#
#                     reach_B    weight_A    weight_B      won_A      won_B  \
# stance_A result
# orthodox draw    178.713339  142.262071  143.685329  26.687410  17.302181
#          win_A   179.800044  148.753390  149.666361  22.336489  13.366736
#          win_B   180.490506  151.113937  151.097547  31.107796  22.045091
# southpaw draw    176.516432  133.227410  135.856707  19.951462  15.155556
# ...

# %%
boxing.groupby(['stance_A', 'result']).size()
# Out:
# stance_A  result
# orthodox  draw        9031
#           win_A     165078
#           win_B      16123
# southpaw  draw        1710
#           win_A      36214
#           win_B       2853
# dtype: int64

# %%
boxing[['result', 'decision']].head()
# Out:
#   result decision
# 0   draw       SD
# 1  win_A       UD
# 2  win_B       KO
# 3  win_A       KO
# 4  win_A       UD

# %%
boxing.groupby('result').age_A.mean()
# Out:
# result
# draw     23.913904
# win_A    24.308861
# win_B    25.605503
# Name: age_A, dtype: float64

# %%
boxing.groupby('won_A').age_A.mean()
# Out:
# won_A
# 0      22.398658
# 1      22.496794
# 2      22.739022
# 3      22.794067
# 4      22.856585
# 5      22.964994
# 6      23.094303
# 7      23.202719
# 8      23.306469
# 9      23.427145
# 10     23.506452
# 11     23.681771
# 12     23.689931
# 13     23.839356
# 14     23.973941
# 15     24.068838
# 16     24.199226
# 17     24.327554
# 18     24.403754
# 19     24.555110
# 20     24.605367
# 21     24.664423
# 22     24.876923
# 23     24.898700
# 24     24.967763
# 25     25.044564
# 26     25.156638
# 27     25.102831
# 28     25.180936
# 29     25.350555
#          ...
# 237    32.250000
# 238    32.500000
# 239    32.500000
# 240    28.666667
# 241    28.666667
# 242    28.500000
# 243    29.666667
# 244    29.666667
# 245    29.666667
# 246    29.666667
# 247    29.666667
# 248    29.666667
# 249    29.666667
# 250    29.666667
# 251    29.666667
# 252    29.666667
# 253    29.500000
# 254    30.000000
# 255    28.750000
# 256    31.000000
# 257    30.666667
# ...

# %%
boxing.groupby('age_A').won_A.sum()
# Out:
# age_A
# -74.0          19
# -4.0            0
#  1.0            1
#  2.0            2
#  5.0            0
#  6.0            4
#  7.0            2
#  8.0           16
#  9.0           75
#  10.0          10
#  11.0          83
#  12.0          30
#  13.0         270
#  14.0        2013
#  15.0        7523
#  16.0       27186
#  17.0       77034
#  18.0      168335
#  19.0      276859
#  20.0      399949
#  21.0      512055
#  22.0      598492
#  23.0      681831
#  24.0      697945
#  25.0      688291
#  26.0      679319
#  27.0      636571
#  28.0      574791
#  29.0      494344
#  30.0      415732
#  31.0      347995
#  32.0      267843
#  33.0      222021
#  34.0      179048
#  35.0      142426
#  36.0      112724
#  37.0       81425
#  38.0       59983
#  39.0       52567
#  40.0       38166
#  41.0       29987
#  42.0       20873
#  43.0       24130
#  44.0       12969
#  45.0        7973
#  46.0        4025
#  47.0        2453
#  48.0        1842
#  49.0        1164
# ...

# %%
#This shows certain rows are invalid even though there is non-null data input
#Anything negative value age and below age 8 should not be included

# %%
boxing.groupby('result').age_B.mean()
# Out:
# result
# draw     24.778714
# win_A    26.977567
# win_B    25.047972
# Name: age_B, dtype: float64

# %%
boxing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 387427 entries, 0 to 387426
# Data columns (total 26 columns):
# age_A       352888 non-null float64
# age_B       257935 non-null float64
# height_A    249246 non-null float64
# height_B    134640 non-null float64
# reach_A     112342 non-null float64
# reach_B     37873 non-null float64
# stance_A    231009 non-null object
# stance_B    231009 non-null object
# weight_A    135573 non-null float64
# weight_B    130358 non-null float64
# won_A       387427 non-null int64
# won_B       387427 non-null int64
# lost_A      387427 non-null int64
# lost_B      387427 non-null int64
# drawn_A     387427 non-null int64
# drawn_B     387427 non-null int64
# kos_A       387427 non-null int64
# kos_B       387348 non-null float64
# result      387427 non-null object
# decision    387427 non-null object
# judge1_A    52248 non-null float64
# judge1_B    52060 non-null float64
# judge2_A    70371 non-null float64
# ...

# %%
#Decided convert ages to from float to int
#Yes, age can technically have a fractional aspect to it but for the purposes of making analysis simpler all entries
#with the same age will be grouped together

# %%
boxing['age_A']= boxing.age_A.astype('int')

#Could not figure out how to get columns with age to finite intergers
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-6a7a5fba6c9e> in <module>()
# ----> 1 boxing['age_A']= boxing.age_A.astype('int')
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     175                 else:
#     176                     kwargs[new_arg_name] = new_arg_value
# --> 177             return func(*args, **kwargs)
#     178         return wrapper
#     179     return _deprecate_kwarg
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4995             # else, only a single dtype is given
#    4996             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 4997                                          **kwargs)
#    4998             return self._constructor(new_data).__finalize__(self)
#    4999
#
# ...

# %%
boxing.age_A.isnull().sum()
# Out:
# 34539

# %%
boxing.age_B.isnull().sum()
# Out:
# 129492

# %%
boxing.result.value_counts()
# Out:
# win_A    321661
# win_B     40994
# draw      24772
# Name: result, dtype: int64

# %%
boxing.decision.value_counts()
# Out:
# PTS    108070
# TKO     89709
# KO      70940
# UD      62290
# NWS     19369
# SD      11323
# MD       9364
# RTD      9065
# DQ       4831
# TD       2466
# Name: decision, dtype: int64

# %%
boxing.judge1_A.value_counts()
# Out:
# 40.0     7529
# 60.0     4326
# 39.0     4264
# 59.0     2562
# 58.0     2136
# 38.0     2136
# 10.0     1757
# 80.0     1692
# 20.0     1270
# 79.0     1122
# 78.0     1092
# 97.0     1081
# 100.0    1080
# 37.0     1014
# 99.0     1009
# 98.0      990
# 116.0     978
# 57.0      976
# 30.0      946
# 77.0      906
# 96.0      881
# 117.0     830
# 115.0     807
# 118.0     764
# 36.0      571
# 119.0     542
# 120.0     541
# 56.0      523
# 95.0      465
# 50.0      452
#          ...
# 235.0       2
# 126.0       2
# 193.0       2
# 240.0       2
# 233.0       2
# 136.0       2
# 124.0       2
# 237.0       2
# 14.0        1
# 24.0        1
# 32.0        1
# 129.0       1
# 239.0       1
# 195.0       1
# 197.0       1
# 125.0       1
# 236.0       1
# 199.0       1
# 540.0       1
# 196.0       1
# 190.0       1
# 31.0        1
# 134.0       1
# 299.0       1
# 234.0       1
# 123.0       1
# 360.0       1
# 223.0       1
# 231.0       1
# 298.0       1
# ...

# %%
boxing.age_B.value_counts(dropna=False)
# Out:
# NaN        129492
#  25.0       20671
#  24.0       20518
#  26.0       20038
#  23.0       19449
#  27.0       18299
#  22.0       17409
#  28.0       16900
#  21.0       14779
#  29.0       14729
#  30.0       12784
#  20.0       11423
#  31.0       10681
#  32.0        9091
#  19.0        8241
#  33.0        7526
#  34.0        6173
#  18.0        5021
#  35.0        4987
#  36.0        4022
#  37.0        3163
#  38.0        2340
#  17.0        2230
#  39.0        1869
#  40.0        1371
#  41.0         914
#  16.0         807
#  42.0         653
#  43.0         448
#  44.0         342
#             ...
#  3.0            2
#  5.0            2
#  101.0          2
#  227.0          2
#  57.0           2
#  1911.0         2
# -6.0            2
#  8.0            2
# -74.0           1
#  102.0          1
#  126.0          1
#  104.0          1
# -1.0            1
#  2016.0         1
#  121.0          1
#  1910.0         1
#  59.0           1
#  921.0          1
#  1817.0         1
# ...

# %%
boxing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 387427 entries, 0 to 387426
# Data columns (total 26 columns):
# age_A       352888 non-null float64
# age_B       257935 non-null float64
# height_A    249246 non-null float64
# height_B    134640 non-null float64
# reach_A     112342 non-null float64
# reach_B     37873 non-null float64
# stance_A    231009 non-null object
# stance_B    231009 non-null object
# weight_A    135573 non-null float64
# weight_B    130358 non-null float64
# won_A       387427 non-null int64
# won_B       387427 non-null int64
# lost_A      387427 non-null int64
# lost_B      387427 non-null int64
# drawn_A     387427 non-null int64
# drawn_B     387427 non-null int64
# kos_A       387427 non-null int64
# kos_B       387348 non-null float64
# result      387427 non-null object
# decision    387427 non-null object
# judge1_A    52248 non-null float64
# judge1_B    52060 non-null float64
# judge2_A    70371 non-null float64
# ...

# %%
boxing.columns
# Out:
# Index(['age_A', 'age_B', 'height_A', 'height_B', 'reach_A', 'reach_B',
#        'stance_A', 'stance_B', 'weight_A', 'weight_B', 'won_A', 'won_B',
#        'lost_A', 'lost_B', 'drawn_A', 'drawn_B', 'kos_A', 'kos_B', 'result',
#        'decision', 'judge1_A', 'judge1_B', 'judge2_A', 'judge2_B', 'judge3_A',
#        'judge3_B'],
#       dtype='object')

# %%
boxing.nlargest(10, 'won_A')
# Out:
#         age_A  age_B  height_A  height_B  reach_A  reach_B  stance_A  \
# 221485   28.0   24.0       NaN       NaN      NaN      NaN       NaN
# 284291   28.0   19.0       NaN     163.0      NaN    168.0       NaN
# 301423   28.0    NaN       NaN       NaN      NaN      NaN       NaN
# 185760   26.0   26.0       NaN     165.0      NaN      NaN       NaN
# 327664   26.0   24.0       NaN       NaN      NaN      NaN       NaN
# 257822   26.0    NaN       NaN       NaN      NaN      NaN       NaN
# 164912   32.0   33.0     173.0     178.0    180.0    193.0  orthodox
# 170272   32.0   33.0     173.0     178.0    180.0    193.0  orthodox
# 164913   32.0   30.0     173.0     179.0    180.0      NaN  orthodox
# 170273   32.0   30.0     173.0     179.0    180.0      NaN  orthodox
#
#         stance_B  weight_A  weight_B   ...     kos_A  kos_B  result  decision  \
# 221485       NaN       NaN       NaN   ...        91   16.0    draw       PTS
# ...

# %%
boxing.iloc[221485]
# Out:
# age_A         28
# age_B         24
# height_A     NaN
# height_B     NaN
# reach_A      NaN
# reach_B      NaN
# stance_A     NaN
# stance_B     NaN
# weight_A     NaN
# weight_B     NaN
# won_A        332
# won_B         63
# lost_A        84
# lost_B        13
# drawn_A       41
# drawn_B        5
# kos_A         91
# kos_B         16
# result      draw
# decision     PTS
# judge1_A     NaN
# judge1_B     NaN
# judge2_A     NaN
# judge2_B     NaN
# judge3_A     NaN
# judge3_B     NaN
# Name: 221485, dtype: object

# %%
boxing['totalfights_A'] = boxing.won_A + boxing.lost_A + boxing.drawn_A

# %%
boxing['totalfights_B'] = boxing.won_B + boxing.lost_B + boxing.drawn_B

# %%
boxing.nlargest(10, 'kos_A')
# Out:
#         age_A  age_B  height_A  height_B  reach_A  reach_B  stance_A  \
# 163938   46.0   39.0     180.0     183.0    191.0      NaN  orthodox
# 163939   45.0   20.0     180.0     191.0    191.0    198.0  orthodox
# 163940   45.0   26.0     180.0     178.0    191.0    183.0  orthodox
# 169298   46.0   39.0     180.0     183.0    191.0      NaN  orthodox
# 169299   45.0   20.0     180.0     191.0    191.0    198.0  orthodox
# 169300   45.0   26.0     180.0     178.0    191.0    183.0  orthodox
# 163941   45.0    NaN     180.0     188.0    191.0      NaN  orthodox
# 169301   45.0    NaN     180.0     188.0    191.0      NaN  orthodox
# 163942   45.0   25.0     180.0     192.0    191.0    185.0  orthodox
# 169302   45.0   25.0     180.0     192.0    191.0    185.0  orthodox
#
#         stance_B  weight_A  weight_B      ...       result  decision  \
# 163938  orthodox     206.0     230.0      ...        win_A       TKO
# ...

# %%
boxing.nsmallest(10, 'totalfights_A')
# Out:
#      age_A  age_B  height_A  height_B  reach_A  reach_B  stance_A  stance_B  \
# 51    15.0   18.0     175.0       NaN    179.0      NaN  orthodox  orthodox
# 83    20.0   26.0     173.0     170.0    178.0      NaN  orthodox  orthodox
# 94    25.0   26.0     170.0     170.0    166.0    166.0  southpaw  southpaw
# 131   24.0   31.0     179.0     179.0    178.0      NaN  orthodox  orthodox
# 200   23.0   32.0     198.0     191.0    208.0      NaN  orthodox  orthodox
# 233   19.0    NaN     170.0       NaN    180.0      NaN  orthodox  orthodox
# 261   18.0   29.0     171.0       NaN    175.0      NaN  orthodox  orthodox
# 286   17.0    NaN     165.0       NaN    167.0      NaN  southpaw  southpaw
# 305   25.0   45.0     175.0       NaN    173.0      NaN  orthodox  orthodox
# 341   18.0   26.0     171.0     160.0    175.0    180.0  orthodox  orthodox
#
#      weight_A  weight_B      ...       result  decision  judge1_A  judge1_B  \
# ...

# %%
boxing.nsmallest(10, 'totalfights_B')
# Out:
#      age_A  age_B  height_A  height_B  reach_A  reach_B  stance_A  stance_B  \
# 42    16.0    NaN     175.0       NaN    179.0      NaN  orthodox  orthodox
# 49    15.0   19.0     175.0     178.0    179.0    183.0  orthodox  orthodox
# 80    20.0   24.0     173.0       NaN    178.0      NaN  orthodox  orthodox
# 134   30.0    NaN     160.0       NaN    161.0      NaN  southpaw  southpaw
# 135   29.0   18.0     160.0     166.0    161.0      NaN  southpaw  southpaw
# 136   29.0    NaN     160.0       NaN    161.0      NaN  southpaw  southpaw
# 151   27.0    NaN     160.0       NaN    161.0      NaN  southpaw  southpaw
# 155   26.0    NaN     160.0       NaN    161.0      NaN  southpaw  southpaw
# 167   24.0    NaN     160.0       NaN    161.0      NaN  southpaw  southpaw
# 168   24.0    NaN     160.0       NaN    161.0      NaN  southpaw  southpaw
#
#      weight_A  weight_B      ...       result  decision  judge1_A  judge1_B  \
# ...

# %%
boxing2 = boxing.dropna()

# %%
boxing['weight_A'].plot(kind = 'hist')

# %%
boxing[['weight_B', 'reach_B']].plot(kind = 'hist')

# %%
boxing.plot(kind='bar', x= 'weight_A', y= 'reach_A')

# %%
boxing.plot.scatter(x='weight_A',y='reach_A')

# %%
boxing.values
# Out:
# array([[35.0, 27.0, 179.0, ..., 113.0, 114.0, 114.0],
#        [26.0, 31.0, 175.0, ..., 108.0, 120.0, 108.0],
#        [28.0, 26.0, 176.0, ..., nan, nan, nan],
#        ...,
#        [20.0, 26.0, nan, ..., nan, nan, nan],
#        [20.0, nan, nan, ..., nan, nan, nan],
#        [20.0, nan, nan, ..., nan, nan, nan]], dtype=object)

# %%
boxing.plot.scatter(x='weight_B',y='reach_B')
